# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
from tqdm.auto import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import torch

from sklearn.ensemble import RandomForestClassifier  # or RandomForestRegressor for regression tasks
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score  # or an appropriate metric for your task
from sklearn.preprocessing import LabelEncoder

# %%
PATH_DATA = '/Users/nicolapitzalis/Documents/uni-ai/HLT/HLT-Project/dataset/ingredients_list_5k_cleaned.csv'
PATH_LABELS = '/Users/nicolapitzalis/Documents/uni-ai/HLT/HLT-Project/dataset/labels_5k.csv'
PATH_VOCABULARY = '/Users/nicolapitzalis/Documents/uni-ai/HLT/HLT-Project/dataset/ingredients_v_5k.csv'

data = pd.read_csv(PATH_DATA)
vocabulary = pd.read_csv(PATH_VOCABULARY)
labels = pd.read_csv(PATH_LABELS)

# %%
vocabulary = vocabulary.fillna('Missing')
ohe_vocabulary = pd.get_dummies(vocabulary, prefix='category').astype(int)  # Replace '0' with the actual column name if it exists

# %%
# Initialize an empty list to hold the one-hot encoded recipes
ohe_matrix = []

# Loop over each recipe in the data
for index, recipe in data.iterrows():
    # Initialize a one-hot encoded array for the recipe
    ohe_recipe = np.zeros(len(ohe_vocabulary.columns))
    
    # Loop over each ingredient in the recipe
    for ingredient in recipe:
        if pd.isnull(ingredient):
            continue
        
        # Check if the ingredient is in the one-hot vocabulary
        if f'category_{ingredient}' in ohe_vocabulary.columns:
            # Find the index for the ingredient
            ingredient_index = ohe_vocabulary.columns.get_loc(f'category_{ingredient}')
            
            # Set the corresponding position in ohe_recipe to 1
            ohe_recipe[ingredient_index] = 1

    # Append the one-hot encoded recipe to the matrix
    ohe_matrix.append(ohe_recipe)

# Convert the list of arrays into a 2D NumPy array
ohe_matrix = np.array(ohe_matrix)

# %%
labels = labels['Vegetarian&Desserts'].to_numpy()

# %%
# Example using a hypothetical dataset
X_train, X_test, y_train, y_test = train_test_split(ohe_matrix, labels, test_size=0.3, random_state=42)

param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]  # Minimum number of samples required to be at a leaf node
}

rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, verbose=2, n_jobs=-1)
grid_search.fit(X_train, y_train)

best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 9.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 6.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 6.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 3.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.8min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 9.7min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.5min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.6min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 6.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 3.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 9.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 6.1min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.9min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.7min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.4min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.3min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.7min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.6min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.6min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.4min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.7min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.1min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.4min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.1min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time= 8.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time= 2.7min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time= 8.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 5.5min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time= 2.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 8.1min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.4min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 5.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 4.3min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 5.2min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 4.9min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 4.8min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 4.7min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 3.0min
# Accuracy: 0.5966666666666667
# Best parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best cross-validation score: 0.62

# %%
X_train, X_test, y_train, y_test = train_test_split(ohe_matrix, labels, test_size=0.3, random_state=42)

random_forest = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=256, min_samples_split=2, min_samples_leaf=2)
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7193333333333334

# %%
from sklearn.tree import export_text

# Loop through each tree in the forest
for i, tree in enumerate(random_forest.estimators_):
    # Export the decision rules
    tree_rules = export_text(tree, feature_names=list(ohe_vocabulary.columns))
    
    # Print the rules for each tree
    print(f"Rules for tree {i}:\n")
    print(tree_rules)
    print("\n")
# Out:
# Rules for tree 0:
#
# |--- category_birds garden peas <= 0.50
# |   |--- category_ground black pepper <= 0.50
# |   |   |--- category_soy sauce <= 0.50
# |   |   |   |--- category_varti cheese <= 0.50
# |   |   |   |   |--- category_chicken stock <= 0.50
# |   |   |   |   |   |--- category_baby asparagus <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_baby asparagus >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chicken stock >  0.50
# |   |   |   |   |   |--- category_red wine <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_red wine >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_varti cheese >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_soy sauce >  0.50
# |   |   |   |--- category_apple sliced <= 0.50
# |   |   |   |   |--- category_minced chives <= 0.50
# |   |   |   |   |   |--- category_sher salt <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_sher salt >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_minced chives >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_apple sliced >  0.50
# |   |   |   |   |--- class: 1.0
# |   |--- category_ground black pepper >  0.50
# |   |   |--- category_belgian endives <= 0.50
# |   |   |   |--- category_ripe peaches <= 0.50
# |   |   |   |   |--- category_chopped fresh parsley leaves <= 0.50
# |   |   |   |   |   |--- category_mussels <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_mussels >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chopped fresh parsley leaves >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_ripe peaches >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_belgian endives >  0.50
# |   |   |   |--- class: 1.0
# |--- category_birds garden peas >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 1:
#
# |--- category_fresh whole <= 0.50
# |   |--- category_ground black pepper <= 0.50
# |   |   |--- category_cinnamon <= 0.50
# |   |   |   |--- category_seasoning salt <= 0.50
# |   |   |   |   |--- category_ribs <= 0.50
# |   |   |   |   |   |--- category_stone white grits <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_stone white grits >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_ribs >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_seasoning salt >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_cinnamon >  0.50
# |   |   |   |--- category_golden raisins <= 0.50
# |   |   |   |   |--- category_vanilla ice cream <= 0.50
# |   |   |   |   |   |--- category_lour divided <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_lour divided >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_vanilla ice cream >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_golden raisins >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_ground black pepper >  0.50
# |   |   |--- category_fresh bay leaves <= 0.50
# |   |   |   |--- category_olive oil <= 0.50
# |   |   |   |   |--- category_mint <= 0.50
# |   |   |   |   |   |--- category_chopped cilantro leaves buns <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_chopped cilantro leaves buns >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_mint >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_olive oil >  0.50
# |   |   |   |   |--- category_chicken <= 0.50
# |   |   |   |   |   |--- category_chopped basil <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_chopped basil >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chicken >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_fresh bay leaves >  0.50
# |   |   |   |--- class: 0.0
# |--- category_fresh whole >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 2:
#
# |--- category_onion <= 0.50
# |   |--- category_ground cinnamon <= 0.50
# |   |   |--- category_ato sauce <= 0.50
# |   |   |   |--- category_smoked bacon <= 0.50
# |   |   |   |   |--- category_medium onion <= 0.50
# |   |   |   |   |   |--- category_gallo <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_gallo >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_medium onion >  0.50
# |   |   |   |   |   |--- category_venison <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_venison >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_smoked bacon >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_ato sauce >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_ground cinnamon >  0.50
# |   |   |--- category_prepared pancake mix <= 0.50
# |   |   |   |--- category_dark raisins <= 0.50
# |   |   |   |   |--- category_turbinado sugar <= 0.50
# |   |   |   |   |   |--- category_pumpkin pie spice butter <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_pumpkin pie spice butter >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_turbinado sugar >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_dark raisins >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_prepared pancake mix >  0.50
# |   |   |   |--- class: 1.0
# |--- category_onion >  0.50
# |   |--- category_rusty bread <= 0.50
# |   |   |--- category_feta <= 0.50
# |   |   |   |--- category_tomato stem <= 0.50
# |   |   |   |   |--- category_madeira <= 0.50
# |   |   |   |   |   |--- category_tomatoes <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_tomatoes >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_madeira >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_tomato stem >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_feta >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_rusty bread >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 3:
#
# |--- category_walnuts <= 0.50
# |   |--- category_white pepper <= 0.50
# |   |   |--- category_minced shallots <= 0.50
# |   |   |   |--- category_selfrising <= 0.50
# |   |   |   |   |--- category_chopped garlic <= 0.50
# |   |   |   |   |   |--- category_shell <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_shell >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chopped garlic >  0.50
# |   |   |   |   |   |--- category_sliced green onion <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_sliced green onion >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_selfrising >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_minced shallots >  0.50
# |   |   |   |--- category_dried thyme <= 0.50
# |   |   |   |   |--- category_pig <= 0.50
# |   |   |   |   |   |--- category_chopped dates <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_chopped dates >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_pig >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_dried thyme >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_white pepper >  0.50
# |   |   |--- category_cloves garlic <= 0.50
# |   |   |   |--- category_venison <= 0.50
# |   |   |   |   |--- category_garlic minced <= 0.50
# |   |   |   |   |   |--- category_virgin <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_virgin >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_garlic minced >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_venison >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_cloves garlic >  0.50
# |   |   |   |--- class: 1.0
# |--- category_walnuts >  0.50
# |   |--- category_bulgur <= 0.50
# |   |   |--- category_balsamic vinegar <= 0.50
# |   |   |   |--- category_sherry vinegar <= 0.50
# |   |   |   |   |--- category_good <= 0.50
# |   |   |   |   |   |--- category_crushed pineapple drained <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_crushed pineapple drained >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_good >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_sherry vinegar >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_balsamic vinegar >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_bulgur >  0.50
# |   |   |--- class: 1.0
#
#
#
# Rules for tree 4:
#
# |--- category_shrimp <= 0.50
# |   |--- category_chicken stock <= 0.50
# |   |   |--- category_shrimp shelled <= 0.50
# |   |   |   |--- category_large onions <= 0.50
# |   |   |   |   |--- category_dried thyme <= 0.50
# |   |   |   |   |   |--- category_ili powder <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_ili powder >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_dried thyme >  0.50
# |   |   |   |   |   |--- category_swordfish steaks flesh <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_swordfish steaks flesh >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_large onions >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_shrimp shelled >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_chicken stock >  0.50
# |   |   |--- category_stoneground mustard <= 0.50
# |   |   |   |--- category_rille between <= 0.50
# |   |   |   |   |--- category_red pepper flakes <= 0.50
# |   |   |   |   |   |--- category_worcestershire sauce <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_worcestershire sauce >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_red pepper flakes >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_rille between >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_stoneground mustard >  0.50
# |   |   |   |--- class: 0.0
# |--- category_shrimp >  0.50
# |   |--- category_fresh <= 0.50
# |   |   |--- category_shell <= 0.50
# |   |   |   |--- category_garlic min <= 0.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_garlic min >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_shell >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_fresh >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 5:
#
# |--- category_egetable oil <= 0.50
# |   |--- category_sher salt <= 0.50
# |   |   |--- category_veal stock <= 0.50
# |   |   |   |--- category_dry red wine <= 0.50
# |   |   |   |   |--- category_coleslaw mix <= 0.50
# |   |   |   |   |   |--- category_mayonnaise <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_mayonnaise >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_coleslaw mix >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_dry red wine >  0.50
# |   |   |   |   |--- category_portobello mushrooms <= 0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_portobello mushrooms >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_veal stock >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_sher salt >  0.50
# |   |   |--- category_hoisin <= 0.50
# |   |   |   |--- category_grated sharp cheddar cheese <= 0.50
# |   |   |   |   |--- category_garlic min <= 0.50
# |   |   |   |   |   |--- category_tomatoes <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_tomatoes >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_garlic min >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_grated sharp cheddar cheese >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_hoisin >  0.50
# |   |   |   |--- class: 1.0
# |--- category_egetable oil >  0.50
# |   |--- category_garlic cloves <= 0.50
# |   |   |--- category_cornstarch <= 0.50
# |   |   |   |--- category_ground black pepper <= 0.50
# |   |   |   |   |--- category_minced parsley <= 0.50
# |   |   |   |   |   |--- category_hot chili sauce <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_hot chili sauce >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_minced parsley >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_ground black pepper >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_cornstarch >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_garlic cloves >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 6:
#
# |--- category_georgiamp <= 0.50
# |   |--- category_eggssher salt <= 0.50
# |   |   |--- category_boneless chicken breasts <= 0.50
# |   |   |   |--- category_spicy <= 0.50
# |   |   |   |   |--- category_cloves <= 0.50
# |   |   |   |   |   |--- category_sour cream <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_sour cream >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_cloves >  0.50
# |   |   |   |   |   |--- category_cubed <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_cubed >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_spicy >  0.50
# |   |   |   |   |--- category_seasoning <= 0.50
# |   |   |   |   |   |--- category_cilantro chopped <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_cilantro chopped >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_seasoning >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_boneless chicken breasts >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_eggssher salt >  0.50
# |   |   |--- category_chopped white onion <= 0.50
# |   |   |   |--- class: 0.0
# |   |   |--- category_chopped white onion >  0.50
# |   |   |   |--- class: 1.0
# |--- category_georgiamp >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 7:
#
# |--- category_dried parsley <= 0.50
# |   |--- category_ground pepper <= 0.50
# |   |   |--- category_fresh thyme <= 0.50
# |   |   |   |--- category_sriracha <= 0.50
# |   |   |   |   |--- category_blue cheese <= 0.50
# |   |   |   |   |   |--- category_ketchup <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_ketchup >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_blue cheese >  0.50
# |   |   |   |   |   |--- category_cooked dice <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_cooked dice >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_sriracha >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_fresh thyme >  0.50
# |   |   |   |--- category_unsalted butter <= 0.50
# |   |   |   |   |--- category_red onions <= 0.50
# |   |   |   |   |   |--- category_mixed mushrooms <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_mixed mushrooms >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_red onions >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_unsalted butter >  0.50
# |   |   |   |   |--- category_light <= 0.50
# |   |   |   |   |   |--- category_ground sage <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_ground sage >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_light >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |--- category_ground pepper >  0.50
# |   |   |--- category_whole black olives <= 0.50
# |   |   |   |--- category_chopped fresh basil <= 0.50
# |   |   |   |   |--- category_tomato paste <= 0.50
# |   |   |   |   |   |--- category_englandstyle hot dog buns <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_englandstyle hot dog buns >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_tomato paste >  0.50
# |   |   |   |   |   |--- category_instant <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_instant >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_chopped fresh basil >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_whole black olives >  0.50
# |   |   |   |--- class: 0.0
# |--- category_dried parsley >  0.50
# |   |--- category_freshly <= 0.50
# |   |   |--- category_dried basil <= 0.50
# |   |   |   |--- class: 1.0
# |   |   |--- category_dried basil >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_freshly >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 8:
#
# |--- category_venison <= 0.50
# |   |--- category_dijon mustard <= 0.50
# |   |   |--- category_ground pepper <= 0.50
# |   |   |   |--- category_veal stock <= 0.50
# |   |   |   |   |--- category_dende oil <= 0.50
# |   |   |   |   |   |--- category_mayonnaise <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_mayonnaise >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_dende oil >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_veal stock >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_ground pepper >  0.50
# |   |   |   |--- category_shredded cheddar cheese <= 0.50
# |   |   |   |   |--- category_ronds <= 0.50
# |   |   |   |   |   |--- category_head <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_head >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_ronds >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_shredded cheddar cheese >  0.50
# |   |   |   |   |--- class: 1.0
# |   |--- category_dijon mustard >  0.50
# |   |   |--- category_feta cheese <= 0.50
# |   |   |   |--- category_honey <= 0.50
# |   |   |   |   |--- category_poblano pepper <= 0.50
# |   |   |   |   |   |--- category_american cheese <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_american cheese >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_poblano pepper >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_honey >  0.50
# |   |   |   |   |--- category_romaine let <= 0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_romaine let >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_feta cheese >  0.50
# |   |   |   |--- class: 1.0
# |--- category_venison >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 9:
#
# |--- category_chopped carrot <= 0.50
# |   |--- category_worcestershire sauce <= 0.50
# |   |   |--- category_bonein <= 0.50
# |   |   |   |--- category_plain <= 0.50
# |   |   |   |   |--- category_boneless <= 0.50
# |   |   |   |   |   |--- category_cajun seasoning <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_cajun seasoning >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_boneless >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_plain >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_bonein >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_worcestershire sauce >  0.50
# |   |   |--- category_roasted red peppers <= 0.50
# |   |   |   |--- category_browned wheat flour <= 0.50
# |   |   |   |   |--- category_avocado <= 0.50
# |   |   |   |   |   |--- category_sharp <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_sharp >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_avocado >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_browned wheat flour >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_roasted red peppers >  0.50
# |   |   |   |--- class: 1.0
# |--- category_chopped carrot >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 10:
#
# |--- category_ketchup <= 0.50
# |   |--- category_boneless chicken breasts <= 0.50
# |   |   |--- category_cheddar <= 0.50
# |   |   |   |--- category_wholewheat <= 0.50
# |   |   |   |   |--- category_chopped chives <= 0.50
# |   |   |   |   |   |--- category_fresh sage <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_fresh sage >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chopped chives >  0.50
# |   |   |   |   |   |--- category_confectioners sugar <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_confectioners sugar >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_wholewheat >  0.50
# |   |   |   |   |--- category_fresh lemon juice <= 0.50
# |   |   |   |   |   |--- category_cloves <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_cloves >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_fresh lemon juice >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_cheddar >  0.50
# |   |   |   |--- category_paprika <= 0.50
# |   |   |   |   |--- category_sour cream <= 0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_sour cream >  0.50
# |   |   |   |   |   |--- category_chopped cilantro leaves <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_chopped cilantro leaves >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_paprika >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_boneless chicken breasts >  0.50
# |   |   |--- class: 0.0
# |--- category_ketchup >  0.50
# |   |--- category_coarse salt <= 0.50
# |   |   |--- category_cloves garlic chopped <= 0.50
# |   |   |   |--- category_apple cider <= 0.50
# |   |   |   |   |--- category_shoyu <= 0.50
# |   |   |   |   |   |--- category_glutenfree buns <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_glutenfree buns >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_shoyu >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_apple cider >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_cloves garlic chopped >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_coarse salt >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 11:
#
# |--- category_pancetta <= 0.50
# |   |--- category_dried white beans <= 0.50
# |   |   |--- category_fresh cilantro <= 0.50
# |   |   |   |--- category_excess fat <= 0.50
# |   |   |   |   |--- category_granulated sugar <= 0.50
# |   |   |   |   |   |--- category_allpurpose flour <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_allpurpose flour >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_granulated sugar >  0.50
# |   |   |   |   |   |--- category_smoked turkey wings <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_smoked turkey wings >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_excess fat >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_fresh cilantro >  0.50
# |   |   |   |--- category_egetable oil <= 0.50
# |   |   |   |   |--- category_chili powder <= 0.50
# |   |   |   |   |   |--- category_fresh garlic <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_fresh garlic >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chili powder >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_egetable oil >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_dried white beans >  0.50
# |   |   |--- class: 0.0
# |--- category_pancetta >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 12:
#
# |--- category_whole butter <= 0.50
# |   |--- category_chopped fresh parsley <= 0.50
# |   |   |--- category_shredded mozzarella <= 0.50
# |   |   |   |--- category_dried thyme <= 0.50
# |   |   |   |   |--- category_green pepper <= 0.50
# |   |   |   |   |   |--- category_minced ginger <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_minced ginger >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_green pepper >  0.50
# |   |   |   |   |   |--- category_beef stew meat <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_beef stew meat >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_dried thyme >  0.50
# |   |   |   |   |--- category_oregano <= 0.50
# |   |   |   |   |   |--- category_sprig <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_sprig >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_oregano >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_shredded mozzarella >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_chopped fresh parsley >  0.50
# |   |   |--- category_caraway seeds <= 0.50
# |   |   |   |--- category_zucchini <= 0.50
# |   |   |   |   |--- category_tomato paste <= 0.50
# |   |   |   |   |   |--- category_fennel seeds <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_fennel seeds >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_tomato paste >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_zucchini >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_caraway seeds >  0.50
# |   |   |   |--- class: 1.0
# |--- category_whole butter >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 13:
#
# |--- category_bay leaf <= 0.50
# |   |--- category_red onions <= 0.50
# |   |   |--- category_fine bread crumbs <= 0.50
# |   |   |   |--- category_rtilla chips <= 0.50
# |   |   |   |   |--- category_sciutto <= 0.50
# |   |   |   |   |   |--- category_freshly <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_freshly >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_sciutto >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_rtilla chips >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_fine bread crumbs >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_red onions >  0.50
# |   |   |--- category_charred flour <= 0.50
# |   |   |   |--- category_warm water <= 0.50
# |   |   |   |   |--- category_red bell peppers <= 0.50
# |   |   |   |   |   |--- category_unsalted butter <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_unsalted butter >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_red bell peppers >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_warm water >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_charred flour >  0.50
# |   |   |   |--- class: 0.0
# |--- category_bay leaf >  0.50
# |   |--- category_tartar <= 0.50
# |   |   |--- category_milk <= 0.50
# |   |   |   |--- category_chopped fresh thyme leaves <= 0.50
# |   |   |   |   |--- category_red wine <= 0.50
# |   |   |   |   |   |--- category_vegetable oil <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_vegetable oil >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_red wine >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_chopped fresh thyme leaves >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_milk >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_tartar >  0.50
# |   |   |--- class: 1.0
#
#
#
# Rules for tree 14:
#
# |--- category_peeled <= 0.50
# |   |--- category_apple cider vinegar <= 0.50
# |   |   |--- category_chopped garlic <= 0.50
# |   |   |   |--- category_breadcrumbs <= 0.50
# |   |   |   |   |--- category_clove garlic minced <= 0.50
# |   |   |   |   |   |--- category_basil salt <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_basil salt >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_clove garlic minced >  0.50
# |   |   |   |   |   |--- category_lemon zested <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_lemon zested >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_breadcrumbs >  0.50
# |   |   |   |   |--- category_pine nuts <= 0.50
# |   |   |   |   |   |--- category_butter <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_butter >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_pine nuts >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_chopped garlic >  0.50
# |   |   |   |--- category_flour <= 0.50
# |   |   |   |   |--- category_minced fresh thyme leaves <= 0.50
# |   |   |   |   |   |--- category_chopped peeled ginger <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_chopped peeled ginger >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_minced fresh thyme leaves >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_flour >  0.50
# |   |   |   |   |--- class: 1.0
# |   |--- category_apple cider vinegar >  0.50
# |   |   |--- category_wholegrain mustard <= 0.50
# |   |   |   |--- category_yellow mustard <= 0.50
# |   |   |   |   |--- category_granny smith apple <= 0.50
# |   |   |   |   |   |--- category_orange zested <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_orange zested >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_granny smith apple >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_yellow mustard >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_wholegrain mustard >  0.50
# |   |   |   |--- class: 0.0
# |--- category_peeled >  0.50
# |   |--- category_allpurpose flour <= 0.50
# |   |   |--- category_white rum <= 0.50
# |   |   |   |--- category_ginger dipping sauce <= 0.50
# |   |   |   |   |--- category_natural almonds skin <= 0.50
# |   |   |   |   |   |--- category_fresh picked cila <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_fresh picked cila >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_natural almonds skin >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_ginger dipping sauce >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_white rum >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_allpurpose flour >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 15:
#
# |--- category_sea scallops <= 0.50
# |   |--- category_vanilla extract <= 0.50
# |   |   |--- category_worcestershire sauce <= 0.50
# |   |   |   |--- category_cracked black pepper <= 0.50
# |   |   |   |   |--- category_earth balance buttery <= 0.50
# |   |   |   |   |   |--- category_sugar <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_sugar >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_earth balance buttery >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_cracked black pepper >  0.50
# |   |   |   |   |--- category_agave syrup <= 0.50
# |   |   |   |   |   |--- category_hiitake king trumpet <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_hiitake king trumpet >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_agave syrup >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_worcestershire sauce >  0.50
# |   |   |   |--- category_shells <= 0.50
# |   |   |   |   |--- category_bay <= 0.50
# |   |   |   |   |   |--- category_thick cut bacon <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_thick cut bacon >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_bay >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_shells >  0.50
# |   |   |   |   |--- class: 1.0
# |   |--- category_vanilla extract >  0.50
# |   |   |--- category_salted butter <= 0.50
# |   |   |   |--- category_granulated sugar <= 0.50
# |   |   |   |   |--- category_melted butter <= 0.50
# |   |   |   |   |   |--- category_peanut brittle recipe <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_peanut brittle recipe >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_melted butter >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_granulated sugar >  0.50
# |   |   |   |   |--- category_evaporated milk <= 0.50
# |   |   |   |   |   |--- category_halved strawberries <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_halved strawberries >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_evaporated milk >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_salted butter >  0.50
# |   |   |   |--- class: 1.0
# |--- category_sea scallops >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 16:
#
# |--- category_onion diced <= 0.50
# |   |--- category_ground chicken <= 0.50
# |   |   |--- category_vanilla extract <= 0.50
# |   |   |   |--- category_fresh thyme <= 0.50
# |   |   |   |   |--- category_tabasco <= 0.50
# |   |   |   |   |   |--- category_freshly grated <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_freshly grated >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_tabasco >  0.50
# |   |   |   |   |   |--- category_cottage cheese <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_cottage cheese >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_fresh thyme >  0.50
# |   |   |   |   |--- category_rigatoni <= 0.50
# |   |   |   |   |   |--- category_firm eggplant <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_firm eggplant >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_rigatoni >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_vanilla extract >  0.50
# |   |   |   |--- category_molasses <= 0.50
# |   |   |   |   |--- category_cocoa <= 0.50
# |   |   |   |   |   |--- category_white chocolate chunk <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_white chocolate chunk >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_cocoa >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_molasses >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_ground chicken >  0.50
# |   |   |--- class: 0.0
# |--- category_onion diced >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 17:
#
# |--- category_chopped onions <= 0.50
# |   |--- category_sharp <= 0.50
# |   |   |--- category_ground beef <= 0.50
# |   |   |   |--- category_spanish onion <= 0.50
# |   |   |   |   |--- category_dried basil <= 0.50
# |   |   |   |   |   |--- category_paprika <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_paprika >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_dried basil >  0.50
# |   |   |   |   |   |--- category_ground red pepper flakes <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_ground red pepper flakes >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_spanish onion >  0.50
# |   |   |   |   |--- category_carrots <= 0.50
# |   |   |   |   |   |--- category_salt <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_salt >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_carrots >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_ground beef >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_sharp >  0.50
# |   |   |--- class: 0.0
# |--- category_chopped onions >  0.50
# |   |--- category_chopped cilantro leaves <= 0.50
# |   |   |--- category_capers <= 0.50
# |   |   |   |--- category_bonein <= 0.50
# |   |   |   |   |--- category_lowsodium chicken broth <= 0.50
# |   |   |   |   |   |--- category_chopped tomatoes <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_chopped tomatoes >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_lowsodium chicken broth >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_bonein >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_capers >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_chopped cilantro leaves >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 18:
#
# |--- category_vanillaf <= 0.50
# |   |--- category_prosciutto <= 0.50
# |   |   |--- category_chicken stock <= 0.50
# |   |   |   |--- category_minced ginger <= 0.50
# |   |   |   |   |--- category_ribs <= 0.50
# |   |   |   |   |   |--- category_shrimp <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_shrimp >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_ribs >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_minced ginger >  0.50
# |   |   |   |   |--- category_chinese black vinegar <= 0.50
# |   |   |   |   |   |--- category_duck <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_duck >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chinese black vinegar >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_chicken stock >  0.50
# |   |   |   |--- category_ned tomatoes <= 0.50
# |   |   |   |   |--- category_processed mozzarella cheese <= 0.50
# |   |   |   |   |   |--- category_cider vinegar <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_cider vinegar >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_processed mozzarella cheese >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_ned tomatoes >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_prosciutto >  0.50
# |   |   |--- class: 0.0
# |--- category_vanillaf >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 19:
#
# |--- category_ground cinnamon <= 0.50
# |   |--- category_mayonnaise <= 0.50
# |   |   |--- category_pancetta <= 0.50
# |   |   |   |--- category_mushroom soup <= 0.50
# |   |   |   |   |--- category_chili powder mixture <= 0.50
# |   |   |   |   |   |--- category_oyster sauce <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_oyster sauce >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chili powder mixture >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_mushroom soup >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_pancetta >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_mayonnaise >  0.50
# |   |   |--- category_brioche buns <= 0.50
# |   |   |   |--- category_dark chocolate <= 0.50
# |   |   |   |   |--- category_scallions <= 0.50
# |   |   |   |   |   |--- category_fine bread crumbs <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_fine bread crumbs >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_scallions >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_dark chocolate >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_brioche buns >  0.50
# |   |   |   |--- class: 0.0
# |--- category_ground cinnamon >  0.50
# |   |--- category_white peppercorns <= 0.50
# |   |   |--- category_mayonnaise <= 0.50
# |   |   |   |--- category_buttermilk <= 0.50
# |   |   |   |   |--- category_boiling water <= 0.50
# |   |   |   |   |   |--- category_sliced domestic mushrooms <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_sliced domestic mushrooms >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_boiling water >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_buttermilk >  0.50
# |   |   |   |   |--- category_whipped cream <= 0.50
# |   |   |   |   |   |--- category_sea salt <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_sea salt >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_whipped cream >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_mayonnaise >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_white peppercorns >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 20:
#
# |--- category_grated ginger <= 0.50
# |   |--- category_sour cream <= 0.50
# |   |   |--- category_excess fat <= 0.50
# |   |   |   |--- category_ewed coffee <= 0.50
# |   |   |   |   |--- category_ground beef <= 0.50
# |   |   |   |   |   |--- category_spanish onion <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_spanish onion >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_ground beef >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_ewed coffee >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_excess fat >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_sour cream >  0.50
# |   |   |--- category_heavy cream <= 0.50
# |   |   |   |--- category_vanilla extract <= 0.50
# |   |   |   |   |--- category_sauce chicken sou <= 0.50
# |   |   |   |   |   |--- category_bakers <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_bakers >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_sauce chicken sou >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_vanilla extract >  0.50
# |   |   |   |   |--- category_egg <= 0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_egg >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_heavy cream >  0.50
# |   |   |   |--- category_cream cheese <= 0.50
# |   |   |   |   |--- category_pistachios <= 0.50
# |   |   |   |   |   |--- category_champagne mango <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_champagne mango >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_pistachios >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_cream cheese >  0.50
# |   |   |   |   |--- class: 1.0
# |--- category_grated ginger >  0.50
# |   |--- category_cloves garlic <= 0.50
# |   |   |--- category_oil <= 0.50
# |   |   |   |--- category_sher salt <= 0.50
# |   |   |   |   |--- category_ground black pepper <= 0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_ground black pepper >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_sher salt >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_oil >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_cloves garlic >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 21:
#
# |--- category_fresh <= 0.50
# |   |--- category_minced garlic <= 0.50
# |   |   |--- category_carrot <= 0.50
# |   |   |   |--- category_white vinegar <= 0.50
# |   |   |   |   |--- category_sour cream <= 0.50
# |   |   |   |   |   |--- category_ground turkey <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_ground turkey >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_sour cream >  0.50
# |   |   |   |   |   |--- category_rmesan <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_rmesan >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_white vinegar >  0.50
# |   |   |   |   |--- category_sour cream <= 0.50
# |   |   |   |   |   |--- category_grapeseed oil <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_grapeseed oil >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_sour cream >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_carrot >  0.50
# |   |   |   |--- category_yellow bell pepper jenne <= 0.50
# |   |   |   |   |--- category_ground <= 0.50
# |   |   |   |   |   |--- category_tomato seeded <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_tomato seeded >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_ground >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_yellow bell pepper jenne >  0.50
# |   |   |   |   |--- class: 1.0
# |   |--- category_minced garlic >  0.50
# |   |   |--- category_ground black pepper oil <= 0.50
# |   |   |   |--- category_shredded <= 0.50
# |   |   |   |   |--- category_kosher salt <= 0.50
# |   |   |   |   |   |--- category_chuck <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_chuck >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_kosher salt >  0.50
# |   |   |   |   |   |--- category_cornmeal <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_cornmeal >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_shredded >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_ground black pepper oil >  0.50
# |   |   |   |--- class: 1.0
# |--- category_fresh >  0.50
# |   |--- category_vegetable stock <= 0.50
# |   |   |--- category_zucchini eggplant <= 0.50
# |   |   |   |--- category_ulienne <= 0.50
# |   |   |   |   |--- category_minced <= 0.50
# |   |   |   |   |   |--- category_flatbread <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_flatbread >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_minced >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_ulienne >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_zucchini eggplant >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_vegetable stock >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 22:
#
# |--- category_virgin <= 0.50
# |   |--- category_pork <= 0.50
# |   |   |--- category_otsots <= 0.50
# |   |   |   |--- category_pico <= 0.50
# |   |   |   |   |--- category_halibut <= 0.50
# |   |   |   |   |   |--- category_ground ginger <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_ground ginger >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_halibut >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_pico >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_otsots >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_pork >  0.50
# |   |   |--- class: 0.0
# |--- category_virgin >  0.50
# |   |--- category_cloves garlic smashed <= 0.50
# |   |   |--- category_loom beefsteak tomatoes <= 0.50
# |   |   |   |--- category_fresh thyme <= 0.50
# |   |   |   |   |--- category_black pepper <= 0.50
# |   |   |   |   |   |--- category_allpose flour <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_allpose flour >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_black pepper >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_fresh thyme >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_loom beefsteak tomatoes >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_cloves garlic smashed >  0.50
# |   |   |--- class: 1.0
#
#
#
# Rules for tree 23:
#
# |--- category_ground sir <= 0.50
# |   |--- category_warm water <= 0.50
# |   |   |--- category_ground beef <= 0.50
# |   |   |   |--- category_boiling water <= 0.50
# |   |   |   |   |--- category_fivespice powder <= 0.50
# |   |   |   |   |   |--- category_chickpeas <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_chickpeas >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_fivespice powder >  0.50
# |   |   |   |   |   |--- category_unenriched cornmeal <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_unenriched cornmeal >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_boiling water >  0.50
# |   |   |   |   |--- category_unflavored gelatin <= 0.50
# |   |   |   |   |   |--- category_salt <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_salt >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_unflavored gelatin >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_ground beef >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_warm water >  0.50
# |   |   |--- category_virgin <= 0.50
# |   |   |   |--- category_water <= 0.50
# |   |   |   |   |--- category_kosher salt <= 0.50
# ...
# |   |   |--- category_celery <= 0.50
# |   |   |   |--- category_chicken stock <= 0.50
# |   |   |   |   |--- category_cooked <= 0.50
# |   |   |   |   |   |--- category_fresh flatleaf parsley <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_fresh flatleaf parsley >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_cooked >  0.50
# |   |   |   |   |   |--- category_carrots <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_carrots >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_chicken stock >  0.50
# |   |   |   |   |--- category_maple syrup <= 0.50
# |   |   |   |   |   |--- category_butter <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_butter >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_maple syrup >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_celery >  0.50
# |   |   |   |--- category_parmesan cheese <= 0.50
# |   |   |   |   |--- category_garlicced <= 0.50
# |   |   |   |   |   |--- category_skin <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_skin >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_garlicced >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_parmesan cheese >  0.50
# |   |   |   |   |--- class: 1.0
# |   |--- category_asparagus spears >  0.50
# |   |   |--- category_fennel seeds <= 0.50
# |   |   |   |--- category_sweet potatoes <= 0.50
# |   |   |   |   |--- category_summer squash <= 0.50
# |   |   |   |   |   |--- category_cold water <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_cold water >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_summer squash >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_sweet potatoes >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_fennel seeds >  0.50
# |   |   |   |--- class: 1.0
# |--- category_toasted sesame seeds >  0.50
# |   |--- class: 0.0
#
#
#
# Rules for tree 94:
#
# |--- category_baking powder <= 0.50
# |   |--- category_frozen peas <= 0.50
# |   |   |--- category_tabasco <= 0.50
# |   |   |   |--- category_sesame seeds <= 0.50
# |   |   |   |   |--- category_vidalia onion <= 0.50
# |   |   |   |   |   |--- category_vegetable <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_vegetable >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_vidalia onion >  0.50
# |   |   |   |   |   |--- category_salt <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_salt >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_sesame seeds >  0.50
# |   |   |   |   |--- category_dark sesame oil <= 0.50
# |   |   |   |   |   |--- category_molasses <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_molasses >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_dark sesame oil >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_tabasco >  0.50
# |   |   |   |--- category_coarse salt <= 0.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_coarse salt >  0.50
# |   |   |   |   |--- class: 1.0
# |   |--- category_frozen peas >  0.50
# |   |   |--- category_cumin seed <= 0.50
# |   |   |   |--- category_crusty bread <= 0.50
# |   |   |   |   |--- category_deli ham <= 0.50
# |   |   |   |   |   |--- category_olive oil <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_olive oil >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_deli ham >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_crusty bread >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_cumin seed >  0.50
# |   |   |   |--- class: 1.0
# |--- category_baking powder >  0.50
# |   |--- category_chopped fresh chives <= 0.50
# |   |   |--- category_onion <= 0.50
# |   |   |   |--- category_honeyroasted peanuts <= 0.50
# |   |   |   |   |--- category_caraway seeds <= 0.50
# |   |   |   |   |   |--- category_navy beans <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_navy beans >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_caraway seeds >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_honeyroasted peanuts >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_onion >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_chopped fresh chives >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 95:
#
# |--- category_flatleaf parsley <= 0.50
# |   |--- category_ground pepper <= 0.50
# |   |   |--- category_minced ginger <= 0.50
# |   |   |   |--- category_applewood smoked bacon <= 0.50
# |   |   |   |   |--- category_eggs <= 0.50
# |   |   |   |   |   |--- category_star anise <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_star anise >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_eggs >  0.50
# |   |   |   |   |   |--- category_freshly <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_freshly >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_applewood smoked bacon >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_minced ginger >  0.50
# |   |   |   |--- category_medium <= 0.50
# |   |   |   |   |--- category_white pepper <= 0.50
# |   |   |   |   |   |--- category_sliced green scallions <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_sliced green scallions >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_white pepper >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_medium >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_ground pepper >  0.50
# |   |   |--- category_anchovy fillets <= 0.50
# |   |   |   |--- category_aigret <= 0.50
# |   |   |   |   |--- category_fat free milk <= 0.50
# |   |   |   |   |   |--- category_clove garlic smashed <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_clove garlic smashed >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_fat free milk >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_aigret >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_anchovy fillets >  0.50
# |   |   |   |--- class: 0.0
# |--- category_flatleaf parsley >  0.50
# |   |--- category_sprig <= 0.50
# |   |   |--- category_prepared <= 0.50
# |   |   |   |--- category_ate <= 0.50
# |   |   |   |   |--- category_lemonsher salt <= 0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_lemonsher salt >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_ate >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_prepared >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_sprig >  0.50
# |   |   |--- category_allfruit <= 0.50
# |   |   |   |--- category_fontina <= 0.50
# |   |   |   |   |--- category_romaine <= 0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_romaine >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_fontina >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_allfruit >  0.50
# |   |   |   |--- class: 0.0
#
#
#
# Rules for tree 96:
#
# |--- category_tomato paste <= 0.50
# |   |--- category_cayenne pepper <= 0.50
# |   |   |--- category_bacon <= 0.50
# |   |   |   |--- category_soy sauce <= 0.50
# |   |   |   |   |--- category_confectioners sugar <= 0.50
# |   |   |   |   |   |--- category_chopped celery <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_chopped celery >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_confectioners sugar >  0.50
# |   |   |   |   |   |--- category_drippings <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_drippings >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_soy sauce >  0.50
# |   |   |   |   |--- category_mirin <= 0.50
# |   |   |   |   |   |--- category_sliced snow peas <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_sliced snow peas >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_mirin >  0.50
# |   |   |   |   |   |--- category_flank steak <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_flank steak >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_bacon >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_cayenne pepper >  0.50
# |   |   |--- category_peanut <= 0.50
# |   |   |   |--- category_sliced almondsopped <= 0.50
# |   |   |   |   |--- category_flounder fillets <= 0.50
# |   |   |   |   |   |--- category_vinerip <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_vinerip >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_flounder fillets >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_sliced almondsopped >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_peanut >  0.50
# |   |   |   |--- class: 1.0
# |--- category_tomato paste >  0.50
# |   |--- category_julienned carrots <= 0.50
# |   |   |--- category_chopped fresh parsley <= 0.50
# |   |   |   |--- category_ripe tomatoes <= 0.50
# |   |   |   |   |--- category_lowsodium vegetable broth <= 0.50
# |   |   |   |   |   |--- category_fresh basil leaves <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_fresh basil leaves >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_lowsodium vegetable broth >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_ripe tomatoes >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_chopped fresh parsley >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_julienned carrots >  0.50
# |   |   |--- class: 1.0
#
#
#
# Rules for tree 97:
#
# |--- category_cloves <= 0.50
# |   |--- category_lowsodium chicken stock <= 0.50
# |   |   |--- category_pork loin <= 0.50
# |   |   |   |--- category_chopped fresh parsley <= 0.50
# |   |   |   |   |--- category_blackberries <= 0.50
# |   |   |   |   |   |--- category_green pepper <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_green pepper >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_blackberries >  0.50
# |   |   |   |   |   |--- category_bon <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_bon >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_chopped fresh parsley >  0.50
# |   |   |   |   |--- category_chopped fresh chives lemon wedges <= 0.50
# |   |   |   |   |   |--- category_stale bread <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_stale bread >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_chopped fresh chives lemon wedges >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_pork loin >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_lowsodium chicken stock >  0.50
# |   |   |--- class: 0.0
# |--- category_cloves >  0.50
# |   |--- category_baby bella <= 0.50
# |   |   |--- category_large shrimp <= 0.50
# |   |   |   |--- category_sher salt <= 0.50
# |   |   |   |   |--- category_tabasco <= 0.50
# |   |   |   |   |   |--- category_pecorino cheese <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_pecorino cheese >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_tabasco >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_sher salt >  0.50
# |   |   |   |   |--- category_whole <= 0.50
# |   |   |   |   |   |--- category_roasted red pepper <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_roasted red pepper >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_whole >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- category_large shrimp >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_baby bella >  0.50
# |   |   |--- class: 1.0
#
#
#
# Rules for tree 98:
#
# |--- category_apple cider vinegar <= 0.50
# |   |--- category_halvedegetable oil <= 0.50
# |   |   |--- category_chopped fresh sage <= 0.50
# |   |   |   |--- category_granulated sugar <= 0.50
# |   |   |   |   |--- category_ado blanche <= 0.50
# |   |   |   |   |   |--- category_clove garlic minced <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_clove garlic minced >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_ado blanche >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_granulated sugar >  0.50
# |   |   |   |   |--- category_whole black peppercorns <= 0.50
# |   |   |   |   |   |--- category_coyote bai <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_coyote bai >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_whole black peppercorns >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- category_chopped fresh sage >  0.50
# |   |   |   |--- class: 0.0
# |   |--- category_halvedegetable oil >  0.50
# |   |   |--- class: 0.0
# |--- category_apple cider vinegar >  0.50
# |   |--- category_cloves garlic grated <= 0.50
# |   |   |--- category_chopped fresh mint <= 0.50
# |   |   |   |--- category_lean pork shoulder <= 0.50
# |   |   |   |   |--- category_eggs <= 0.50
# |   |   |   |   |   |--- category_balsamic vinegar <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_balsamic vinegar >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_eggs >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_lean pork shoulder >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_chopped fresh mint >  0.50
# |   |   |   |--- class: 1.0
# |   |--- category_cloves garlic grated >  0.50
# |   |   |--- class: 0.0
#
#
#
# Rules for tree 99:
#
# |--- category_lowsodium chicken stock <= 0.50
# |   |--- category_lour <= 0.50
# |   |   |--- category_hot sauce <= 0.50
# |   |   |   |--- category_spanish olive oil <= 0.50
# |   |   |   |   |--- category_soy sauce <= 0.50
# |   |   |   |   |   |--- category_ground black pepper <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- category_ground black pepper >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_soy sauce >  0.50
# |   |   |   |   |   |--- category_lamb rib chops allice <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_lamb rib chops allice >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_spanish olive oil >  0.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- category_hot sauce >  0.50
# |   |   |   |--- category_corn tortilla chips <= 0.50
# |   |   |   |   |--- category_corn <= 0.50
# |   |   |   |   |   |--- category_fuji apple <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_fuji apple >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- category_corn >  0.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- category_corn tortilla chips >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- category_lour >  0.50
# |   |   |--- category_cooked brown <= 0.50
# |   |   |   |--- category_chopped pine nuts <= 0.50
# |   |   |   |   |--- category_ground nutmeg <= 0.50
# |   |   |   |   |   |--- category_pitted black olives <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- category_pitted black olives >  0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- category_ground nutmeg >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- category_chopped pine nuts >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- category_cooked brown >  0.50
# |   |   |   |--- class: 0.0
# |--- category_lowsodium chicken stock >  0.50
# |   |--- class: 0.0

# %%
from sklearn.tree import export_text

# Loop through each tree in the forest
for i, tree in enumerate(best_rf.estimators_):
    # Export the decision rules
    tree_rules = export_text(tree, feature_names=list(ohe_vocabulary.columns))
    
    # Print the rules for each tree
    print(f"Rules for tree {i}:\n")
    print(tree_rules)
    print("\n")
# Out:
# Rules for tree 0:
#
# |--- class: 1.0
#
#
#
# Rules for tree 1:
#
# |--- class: 1.0
#
#
#
# Rules for tree 2:
#
# |--- class: 1.0
#
#
#
# Rules for tree 3:
#
# |--- class: 1.0
#
#
#
# Rules for tree 4:
#
# |--- class: 1.0
#
#
#
# Rules for tree 5:
#
# |--- class: 1.0
#
#
#
# Rules for tree 6:
#
# |--- class: 1.0
#
#
#
# Rules for tree 7:
#
# |--- class: 1.0
#
#
#
# Rules for tree 8:
#
# |--- class: 1.0
#
#
#
# Rules for tree 9:
#
# |--- class: 1.0
#
#
#
# Rules for tree 10:
#
# |--- class: 1.0
#
#
#
# Rules for tree 11:
#
# |--- class: 1.0
#
#
#
# Rules for tree 12:
#
# |--- class: 1.0
#
#
#
# Rules for tree 13:
#
# |--- class: 1.0
#
#
#
# Rules for tree 14:
#
# |--- class: 1.0
#
#
#
# Rules for tree 15:
#
# |--- class: 1.0
#
#
#
# Rules for tree 16:
#
# |--- class: 1.0
#
#
#
# Rules for tree 17:
#
# |--- class: 1.0
#
#
#
# Rules for tree 18:
#
# |--- class: 1.0
#
#
#
# Rules for tree 19:
#
# |--- class: 1.0
#
#
#
# Rules for tree 20:
#
# |--- class: 1.0
#
#
#
# Rules for tree 21:
#
# |--- class: 1.0
#
#
#
# Rules for tree 22:
#
# |--- class: 1.0
#
#
#
# Rules for tree 23:
#
# |--- class: 1.0
#
#
#
# Rules for tree 24:
#
# |--- class: 1.0
#
#
#
# Rules for tree 25:
#
# |--- class: 1.0
#
#
#
# Rules for tree 26:
#
# |--- class: 1.0
#
#
#
# Rules for tree 27:
#
# |--- class: 1.0
#
#
#
# Rules for tree 28:
#
# |--- class: 1.0
#
#
#
# Rules for tree 29:
#
# |--- class: 1.0
#
#
#
# Rules for tree 30:
#
# |--- class: 1.0
#
#
#
# Rules for tree 31:
#
# |--- class: 1.0
#
#
#
# Rules for tree 32:
#
# |--- class: 1.0
#
#
#
# Rules for tree 33:
#
# |--- class: 1.0
#
#
#
# Rules for tree 34:
#
# |--- class: 1.0
#
#
#
# Rules for tree 35:
#
# |--- class: 1.0
#
#
#
# Rules for tree 36:
#
# |--- class: 1.0
#
#
#
# Rules for tree 37:
#
# |--- class: 1.0
#
#
#
# Rules for tree 38:
#
# |--- class: 1.0
#
#
#
# Rules for tree 39:
#
# |--- class: 1.0
#
#
#
# Rules for tree 40:
#
# |--- class: 1.0
#
#
#
# Rules for tree 41:
#
# |--- class: 1.0
#
#
#
# Rules for tree 42:
#
# |--- class: 1.0
#
#
#
# Rules for tree 43:
#
# |--- class: 1.0
#
#
#
# Rules for tree 44:
#
# |--- class: 1.0
#
#
#
# Rules for tree 45:
#
# |--- class: 1.0
#
#
#
# Rules for tree 46:
#
# |--- class: 1.0
#
#
#
# Rules for tree 47:
#
# |--- class: 1.0
#
#
#
# Rules for tree 48:
#
# |--- class: 1.0
#
#
#
# Rules for tree 49:
#
# |--- class: 1.0
#
#
#
# Rules for tree 50:
#
# |--- class: 1.0
#
#
#
# Rules for tree 51:
#
# |--- class: 1.0
#
#
#
# Rules for tree 52:
#
# |--- class: 1.0
#
#
#
# Rules for tree 53:
#
# |--- class: 1.0
#
#
#
# Rules for tree 54:
#
# |--- class: 1.0
#
#
#
# Rules for tree 55:
#
# |--- class: 1.0
#
#
#
# Rules for tree 56:
#
# |--- class: 1.0
#
#
#
# Rules for tree 57:
#
# |--- class: 1.0
#
#
#
# Rules for tree 58:
#
# |--- class: 1.0
#
#
#
# Rules for tree 59:
#
# |--- class: 1.0
#
#
#
# Rules for tree 60:
#
# |--- class: 1.0
#
#
#
# Rules for tree 61:
#
# |--- class: 1.0
#
#
#
# Rules for tree 62:
#
# |--- class: 1.0
#
#
#
# Rules for tree 63:
#
# |--- class: 1.0
#
#
#
# Rules for tree 64:
#
# |--- class: 1.0
#
#
#
# Rules for tree 65:
#
# |--- class: 1.0
#
#
#
# Rules for tree 66:
#
# |--- class: 1.0
#
#
#
# Rules for tree 67:
#
# |--- class: 1.0
#
#
#
# Rules for tree 68:
#
# |--- class: 1.0
#
#
#
# Rules for tree 69:
#
# |--- class: 1.0
#
#
#
# Rules for tree 70:
#
# |--- class: 1.0
#
#
#
# Rules for tree 71:
#
# |--- class: 1.0
#
#
#
# Rules for tree 72:
#
# |--- class: 1.0
#
#
#
# Rules for tree 73:
#
# |--- class: 1.0
#
#
#
# Rules for tree 74:
#
# |--- class: 1.0
#
#
#
# Rules for tree 75:
#
# |--- class: 1.0
#
#
#
# Rules for tree 76:
#
# |--- class: 1.0
#
#
#
# Rules for tree 77:
#
# |--- class: 1.0
#
#
#
# Rules for tree 78:
#
# |--- class: 1.0
#
#
#
# Rules for tree 79:
#
# |--- class: 1.0
#
#
#
# Rules for tree 80:
#
# |--- class: 1.0
#
#
#
# Rules for tree 81:
#
# |--- class: 1.0
#
#
#
# Rules for tree 82:
#
# |--- class: 1.0
#
#
#
# Rules for tree 83:
#
# |--- class: 1.0
#
#
#
# Rules for tree 84:
#
# |--- class: 1.0
#
#
#
# Rules for tree 85:
#
# |--- class: 1.0
#
#
#
# Rules for tree 86:
#
# |--- class: 1.0
#
#
#
# Rules for tree 87:
#
# |--- class: 1.0
#
#
#
# Rules for tree 88:
#
# |--- class: 1.0
#
#
#
# Rules for tree 89:
#
# |--- class: 1.0
#
#
#
# Rules for tree 90:
#
# |--- class: 1.0
#
#
#
# Rules for tree 91:
#
# |--- class: 1.0
#
#
#
# Rules for tree 92:
#
# |--- class: 1.0
#
#
#
# Rules for tree 93:
#
# |--- class: 1.0
#
#
#
# Rules for tree 94:
#
# |--- class: 1.0
#
#
#
# Rules for tree 95:
#
# |--- class: 1.0
#
#
#
# Rules for tree 96:
#
# |--- class: 1.0
#
#
#
# Rules for tree 97:
#
# |--- class: 1.0
#
#
#
# Rules for tree 98:
#
# |--- class: 1.0
#
#
#
# Rules for tree 99:
#
# |--- class: 1.0

# %%
np.unique(ohe_matrix)
# Out:
# array([0., 1.])

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Binarizer
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(ohe_matrix, labels, test_size=0.2, random_state=42, stratify=labels)

# Setup the RBM with a Logistic Regression classifier in a pipeline
rbm = BernoulliRBM(random_state=42, verbose=True)
logistic = LogisticRegression(max_iter=1000)

classifier = Pipeline(steps=[('rbm', rbm), ('logistic', logistic)])

# Grid search parameters
param_grid = {
    'rbm__learning_rate': [0.01, 0.1, 0.5],
    'rbm__n_iter': [20, 40, 80],
    'rbm__n_components': [50, 100, 200]  # number of hidden units
}

# Using GridSearchCV to find the best parameters
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(classifier, param_grid, n_jobs=-1, cv=3)
grid_search.fit(X_train, y_train)

# Best parameters and scores
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))

# Evaluate the model
y_pred = grid_search.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Binarizer
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Assuming ohe_matrix and labels are your data and labels loaded previously

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(ohe_matrix, labels, test_size=0.2, random_state=42, stratify=labels)

# Setup the RBM with specified hyperparameters and Logistic Regression classifier in a pipeline
rbm = BernoulliRBM(n_components=100, learning_rate=0.1, n_iter=40, random_state=42, verbose=True)
logistic = LogisticRegression(max_iter=1000)

classifier = Pipeline(steps=[('rbm', rbm), ('logistic', logistic)])

# Train the classifier
classifier.fit(X_train, y_train)

# Evaluate the classifier
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -81.88, time = 7.75s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -86.19, time = 7.58s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -84.68, time = 7.66s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -118.27, time = 7.90s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -92.78, time = 8.39s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -88.60, time = 8.72s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -80.56, time = 8.54s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -67.89, time = 8.47s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -79.63, time = 9.11s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -82.80, time = 8.89s
# [BernoulliRBM] Iteration 11, pseudo-likelihood = -94.19, time = 8.80s
# [BernoulliRBM] Iteration 12, pseudo-likelihood = -78.43, time = 8.24s
# [BernoulliRBM] Iteration 13, pseudo-likelihood = -74.51, time = 8.17s
# [BernoulliRBM] Iteration 14, pseudo-likelihood = -84.17, time = 7.87s
# [BernoulliRBM] Iteration 15, pseudo-likelihood = -97.83, time = 7.72s
# [BernoulliRBM] Iteration 16, pseudo-likelihood = -95.67, time = 8.21s
# [BernoulliRBM] Iteration 17, pseudo-likelihood = -94.08, time = 8.30s
# [BernoulliRBM] Iteration 18, pseudo-likelihood = -96.55, time = 8.30s
# [BernoulliRBM] Iteration 19, pseudo-likelihood = -90.53, time = 8.18s
# [BernoulliRBM] Iteration 20, pseudo-likelihood = -83.23, time = 7.78s
# [BernoulliRBM] Iteration 21, pseudo-likelihood = -93.48, time = 7.69s
# [BernoulliRBM] Iteration 22, pseudo-likelihood = -93.74, time = 7.64s
# [BernoulliRBM] Iteration 23, pseudo-likelihood = -76.18, time = 7.63s
# [BernoulliRBM] Iteration 24, pseudo-likelihood = -77.89, time = 7.62s
# [BernoulliRBM] Iteration 25, pseudo-likelihood = -72.94, time = 7.53s
# [BernoulliRBM] Iteration 26, pseudo-likelihood = -94.47, time = 7.61s
# [BernoulliRBM] Iteration 27, pseudo-likelihood = -81.50, time = 8.20s
# [BernoulliRBM] Iteration 28, pseudo-likelihood = -92.26, time = 8.12s
# [BernoulliRBM] Iteration 29, pseudo-likelihood = -88.83, time = 7.73s
# [BernoulliRBM] Iteration 30, pseudo-likelihood = -85.94, time = 7.63s
# [BernoulliRBM] Iteration 31, pseudo-likelihood = -90.57, time = 7.88s
# [BernoulliRBM] Iteration 32, pseudo-likelihood = -87.61, time = 7.59s
# [BernoulliRBM] Iteration 33, pseudo-likelihood = -96.89, time = 7.56s
# [BernoulliRBM] Iteration 34, pseudo-likelihood = -78.49, time = 7.65s
# [BernoulliRBM] Iteration 35, pseudo-likelihood = -84.50, time = 7.64s
# [BernoulliRBM] Iteration 36, pseudo-likelihood = -79.12, time = 7.53s
# [BernoulliRBM] Iteration 37, pseudo-likelihood = -108.01, time = 7.58s
# [BernoulliRBM] Iteration 38, pseudo-likelihood = -82.64, time = 7.52s
# [BernoulliRBM] Iteration 39, pseudo-likelihood = -90.38, time = 7.62s
# [BernoulliRBM] Iteration 40, pseudo-likelihood = -76.99, time = 7.55s
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       388
#            1       0.61      1.00      0.76       612
#
#     accuracy                           0.61      1000
#    macro avg       0.31      0.50      0.38      1000
# weighted avg       0.37      0.61      0.46      1000
# /Users/nicolapitzalis/anaconda3/envs/hlt/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/nicolapitzalis/anaconda3/envs/hlt/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/nicolapitzalis/anaconda3/envs/hlt/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
